# %% [markdown]
# ![Captura de pantalla 2024-03-01 232238.png](data:image/png;base64,...)

# %% [markdown]
# ###Ejemplo 1: Como calcular la media, mediana y moda

# %%
from statistics import mean, median, mode

# %%
# Lista de calificaciones del grupo a de probabilidad y estadistica
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# La funcion type nos devuelve el tipo de dato dela variable
type(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
# list

# %%
from statistics import mean, median, mode

# Sacar La media de las calificaciones con una formula
promedio = sum(grupoa) / len(grupoa)
print(promedio)

# Utilizar la funcion mean que esta en la libreria statistics para sacar # el promedio
promedio2 = mean(grupoa)
print(promedio2)

# Determinar el valor de la mediana con la funcion median
mediana= median(grupoa)
print(mediana)

# Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 75.33333333333333
# 75.33333333333333
# 76.5
# 70

# %% [markdown]
# ###Ejemplo 2: Estadisticas de corredores en 100 metros

# %%
# Definimos una varaiable Llamada tiempos100mts de tipo lista, que contiene Los #tiempos que tardaron Los 10 alumnos para correr Los 100 metros tiempos100mts = [115.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
# Desplegamos Los valores de la lista print(tiempos100mts)
tiempos100mts= [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
print("El tiempo de los corredores es=>", (tiempos100mts))

# Usamos La funcion mean para determinar el tiempo promedio de la lista de valores
print("El tiempo promedio de los corredores es=>", mean(tiempos100mts))
# Out:
# El tiempo de los corredores es=> [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]
# El tiempo promedio de los corredores es=> 17.322

# %%
# Usamos La funcion median para determinar el tiempo promedio de la lista de valores
#definimos una variable Llammada mediana par calcular La mediana de la lista con la funcion # median
mediana = median (tiempos100mts)
print("La media de los tiempos de los corredores es=>", mediana)

#definimos una variable Llammada moda par calcular la moda de la lista con la funcion # mode
moda=mode(tiempos100mts)
print("La moda de los tiempos es=>", moda)

multimodas= multimode(tiempos100mts)
print("La moda de los tiempos es=>", multimodas)
# Out:
# La media de los tiempos de los corredores es=> 17.2
# La moda de los tiempos es=> 15.1
# La moda de los tiempos es=> [15.1, 17.2]

# %% [markdown]
# ###Ejemplo 3: Histogramas de 2 grupos

# %%
# Libreria para generar numeros aleatorios
import random
from statistics import*

# %%
fabrica1 = []
for i in range(100):
   numero_aleatorio = round (random.uniform(50, 100), 2 )
   fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [53.13, 50.29, 79.11, 61.82, 77.73, 75.16, 57.59, 93.45, 79.16, 73.93, 51.63, 78.92, 66.04, 85.48, 75.99, 77.62, 98.78, 93.41, 76.06, 85.67, 87.58, 75.64, 92.23, 82.8, 94.29, 81.03, 98.74, 82.95, 71.2, 96.68, 89.74, 85.15, 59.45, 74.97, 67.92, 51.18, 65.69, 66.49, 53.58, 51.91, 86.51, 51.29, 51.06, 90.29, 54.21, 97.04, 96.0, 87.55, 59.83, 66.4, 82.35, 59.22, 65.03, 60.91, 70.24, 90.94, 76.35, 80.93, 52.5, 64.98, 64.41, 53.01, 52.46, 77.0, 75.7, 54.77, 57.12, 59.15, 94.93, 52.2, 65.8, 84.44, 86.39, 67.09, 60.2, 73.04, 82.67, 98.13, 91.98, 60.1, 69.55, 96.26, 83.73, 90.61, 57.44, 91.39, 89.09, 77.21, 78.24, 82.23, 52.06, 63.05, 76.93, 78.79, 66.73, 86.93, 82.07, 78.82, 69.92, 63.2]

# %%
fabrica2 = []
for i in range(100):
   numero_aleatorio = round (random.uniform(50, 100), 2 )
   fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [80.0, 69.73, 75.7, 98.67, 52.02, 50.15, 62.43, 65.87, 66.32, 82.36, 67.34, 96.98, 64.5, 94.17, 73.1, 55.76, 96.05, 91.82, 73.21, 60.75, 67.6, 79.17, 88.44, 94.56, 71.21, 72.24, 92.19, 57.08, 81.26, 62.32, 80.3, 52.57, 74.54, 70.74, 79.47, 77.96, 66.81, 60.83, 87.52, 59.26, 51.39, 82.21, 86.28, 50.75, 79.08, 94.68, 92.83, 51.24, 80.86, 93.66, 82.56, 56.07, 86.5, 97.31, 64.05, 67.61, 78.27, 70.88, 79.59, 55.99, 55.23, 85.92, 96.85, 81.4, 52.05, 79.61, 56.31, 92.06, 52.81, 61.34, 87.33, 83.38, 74.07, 67.95, 93.44, 64.96, 78.91, 52.36, 82.88, 81.66, 62.74, 90.37, 54.59, 68.07, 99.79, 93.96, 82.71, 76.91, 56.57, 63.7, 69.01, 75.29, 98.93, 89.5, 98.92, 73.29, 91.96, 96.11, 64.62, 81.37]

# %%
# libreia de python para graficar valores|
import matplotlib.pyplot as plt

plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
plt.hist(fabrica1, color='thistle')
# Out:
# (array([15.,  7.,  7., 11.,  5., 18.,  9.,  9., 10.,  9.]),
#  array([50.29 , 55.139, 59.988, 64.837, 69.686, 74.535, 79.384, 84.233,
#         89.082, 93.931, 98.78 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2")
plt.hist(fabrica2, color='palevioletred')
# Out:
# (array([10.,  8., 11., 10.,  9., 11., 13.,  7., 12.,  9.]),
#  array([50.15 , 55.114, 60.078, 65.042, 70.006, 74.97 , 79.934, 84.898,
#         89.862, 94.826, 99.79 ]),
#  <BarContainer object of 10 artists>)

# %%
media = mean(fabrica1)
mediana = median(fabrica1)
moda= mode(fabrica1)
print("Valores de la fabrica 1")
print("La media es =", media)
print("la mediana es =", mediana)
print("la moda es =", moda)
# Out:
# Valores de la fabrica 1
# La media es = 74.0866
# la mediana es = 76.025
# la moda es = 53.13

# %%
media = mean(fabrica2)
mediana = median(fabrica2)
moda = mode(fabrica2)
print("Valores de la fabrica 2")
print("La media es =", media)
print("la mediana es =", mediana)
print("la moda es =", moda)
# Out:
# Valores de la fabrica 2
# La media es = 75.2374
# la mediana es = 76.305
# la moda es = 80.0

# %%
# generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas,
# una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)

ax1.hist(fabrica1, color='lightpink')
ax2.hist(fabrica2, color='lightblue')
# Out:
# (array([10.,  8., 11., 10.,  9., 11., 13.,  7., 12.,  9.]),
#  array([50.15 , 55.114, 60.078, 65.042, 70.006, 74.97 , 79.934, 84.898,
#         89.862, 94.826, 99.79 ]),
#  <BarContainer object of 10 artists>)

# %%
# generar 2 subplot de 1 renglon por 2 columnas para desplegar los 2 histogramas,
# una al lado de la otra
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2)

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1= mode(fabrica1)
plt.hist(fabrica1, bins=10, alpha=0.2, color='plum', edgecolor = "magenta")
plt.axvline(media1, color='hotpink', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='cornflowerblue', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='mediumorchid', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 1")
plt.legend()
plt.show()

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2= mode(fabrica2)
plt.hist(fabrica2, bins=10, alpha=0.2, color='plum', edgecolor = "magenta")
plt.axvline(media2, color='hotpink', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='cornflowerblue', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='mediumorchid', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title("Producción diaria de la fabrica 2")
plt.legend()
plt.show()

# %% [markdown]
# ###Ejemplo 4 :Maximo, minimmo y rango

# %%
maximo = max(fabrica1)
minimo = min(fabrica1)
rango = maximo - minimo
media = mean(fabrica1)
mediana = median(fabrica1)
moda = mode (fabrica1)
print( "Estadistica descriptiva de la Fabrica 1 \n", "Media =", media,
"\n Mediana =", mediana, "\n Moda =", moda, "\n Maximo = ", maximo,
"\n Minimo =", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 74.0866
#  Mediana = 76.025
#  Moda = 53.13
#  Maximo =  98.78
#  Minimo = 50.29
#  Rango = 48.49

# %%
maximo = max(fabrica2)
minimo = min(fabrica2)
rango = maximo - minimo
media = mean(fabrica2)
mediana = median(fabrica2)
moda = mode (fabrica2)
print( "Estadistica descriptiva de la Fabrica 2 \n", "Media =", media,
"\n Mediana =", mediana, "\n Moda =", moda, "\n Maximo = ", maximo,
"\n Minimo =", minimo, "\n Rango =", rango)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 75.2374
#  Mediana = 76.305
#  Moda = 80.0
#  Maximo =  99.79
#  Minimo = 50.15
#  Rango = 49.64000000000001

# %% [markdown]
# ###Ejemplo 5: Tabla de frecuencias

# %%
# generamos una lista vacia que representa la edad de un grupo de personas

edades = []
for i in range(100):
  numero_aleatorio = random.randint(18,70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [54, 58, 59, 30, 51, 51, 50, 56, 70, 25, 23, 22, 30, 19, 43, 68, 38, 23, 37, 22, 48, 40, 46, 52, 38, 62, 62, 55, 66, 28, 30, 40, 46, 59, 50, 29, 37, 70, 18, 39, 51, 70, 60, 47, 39, 33, 37, 68, 29, 44, 35, 45, 67, 70, 52, 29, 32, 44, 55, 69, 20, 49, 25, 41, 53, 46, 30, 35, 34, 36, 31, 43, 18, 48, 54, 64, 31, 69, 23, 48, 43, 68, 56, 49, 22, 39, 54, 70, 48, 40, 70, 67, 66, 54, 26, 29, 37, 22, 39, 49]

# %%
import pandas as pd
df_edades = pd.DataFrame (edades, columns=["Edad"])
df_edades
# Out:
#     Edad
# 0     54
# 1     58
# 2     59
# 3     30
# 4     51
# ..   ...
# 95    29
# 96    37
# 97    22
# 98    39
# 99    49
#
# [100 rows x 1 columns]

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df_edades ["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 0     70           6
# 1     54           4
# 2     39           4
# 3     48           4
# 4     37           4
# 5     29           4
# 6     22           4
# 7     30           4
# 8     23           3
# 9     49           3
# 10    43           3
# 11    68           3
# 12    51           3
# 13    40           3
# 14    46           3
# 15    69           2
# 16    67           2
# 17    35           2
# 18    44           2
# 19    31           2
# 20    18           2
# 21    66           2
# 22    25           2
# 23    55           2
# 24    62           2
# 25    52           2
# 26    59           2
# 27    38           2
# 28    50           2
# 29    56           2
# 30    20           1
# 31    64           1
# 32    36           1
# 33    34           1
# 34    53           1
# 35    41           1
# 36    58           1
# 37    32           1
# 38    28           1
# 39    45           1
# 40    19           1
# 41    33           1
# 42    47           1
# 43    60           1
# 44    26           1

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df_edades["Edad"].value_counts().reset_index()
tabla_frecuencias.columns = ["Edad", "Frecuencia"]
tabla_frecuencias = tabla_frecuencias.sort_values (by = "Edad")
tabla_frecuencias
# Out:
#     Edad  Frecuencia
# 20    18           2
# 40    19           1
# 30    20           1
# 6     22           4
# 8     23           3
# 22    25           2
# 44    26           1
# 38    28           1
# 5     29           4
# 7     30           4
# 19    31           2
# 37    32           1
# 41    33           1
# 33    34           1
# 17    35           2
# 32    36           1
# 4     37           4
# 27    38           2
# 2     39           4
# 13    40           3
# 35    41           1
# 10    43           3
# 18    44           2
# 39    45           1
# 14    46           3
# 42    47           1
# 3     48           4
# 9     49           3
# 28    50           2
# 12    51           3
# 25    52           2
# 34    53           1
# 1     54           4
# 23    55           2
# 29    56           2
# 36    58           1
# 26    59           2
# 43    60           1
# 24    62           2
# 31    64           1
# 21    66           2
# 16    67           2
# 11    68           3
# 15    69           2
# 0     70           6

# %%
# Tabla de frecuencia relativa
tabla_frecuencias ["Frec. Relativa"] = tabla_frecuencias ["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa
# 20    18           2            0.02
# 40    19           1            0.01
# 30    20           1            0.01
# 6     22           4            0.04
# 8     23           3            0.03
# 22    25           2            0.02
# 44    26           1            0.01
# 38    28           1            0.01
# 5     29           4            0.04
# 7     30           4            0.04
# 19    31           2            0.02
# 37    32           1            0.01
# 41    33           1            0.01
# 33    34           1            0.01
# 17    35           2            0.02
# 32    36           1            0.01
# 4     37           4            0.04
# 27    38           2            0.02
# 2     39           4            0.04
# 13    40           3            0.03
# 35    41           1            0.01
# 10    43           3            0.03
# 18    44           2            0.02
# 39    45           1            0.01
# 14    46           3            0.03
# 42    47           1            0.01
# 3     48           4            0.04
# 9     49           3            0.03
# 28    50           2            0.02
# 12    51           3            0.03
# 25    52           2            0.02
# 34    53           1            0.01
# 1     54           4            0.04
# 23    55           2            0.02
# 29    56           2            0.02
# 36    58           1            0.01
# 26    59           2            0.02
# 43    60           1            0.01
# 24    62           2            0.02
# 31    64           1            0.01
# 21    66           2            0.02
# 16    67           2            0.02
# 11    68           3            0.03
# 15    69           2            0.02
# 0     70           6            0.06

# %%
# Tabla de frecuencia porcentual
tabla_frecuencias ["Frec. Porcentual"] = tabla_frecuencias ["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual
# 20    18           2            0.02               2.0
# 40    19           1            0.01               1.0
# 30    20           1            0.01               1.0
# 6     22           4            0.04               4.0
# 8     23           3            0.03               3.0
# 22    25           2            0.02               2.0
# 44    26           1            0.01               1.0
# 38    28           1            0.01               1.0
# 5     29           4            0.04               4.0
# 7     30           4            0.04               4.0
# 19    31           2            0.02               2.0
# 37    32           1            0.01               1.0
# 41    33           1            0.01               1.0
# 33    34           1            0.01               1.0
# 17    35           2            0.02               2.0
# 32    36           1            0.01               1.0
# 4     37           4            0.04               4.0
# 27    38           2            0.02               2.0
# 2     39           4            0.04               4.0
# 13    40           3            0.03               3.0
# 35    41           1            0.01               1.0
# 10    43           3            0.03               3.0
# 18    44           2            0.02               2.0
# 39    45           1            0.01               1.0
# 14    46           3            0.03               3.0
# 42    47           1            0.01               1.0
# 3     48           4            0.04               4.0
# 9     49           3            0.03               3.0
# 28    50           2            0.02               2.0
# 12    51           3            0.03               3.0
# 25    52           2            0.02               2.0
# 34    53           1            0.01               1.0
# 1     54           4            0.04               4.0
# 23    55           2            0.02               2.0
# 29    56           2            0.02               2.0
# 36    58           1            0.01               1.0
# 26    59           2            0.02               2.0
# 43    60           1            0.01               1.0
# 24    62           2            0.02               2.0
# 31    64           1            0.01               1.0
# 21    66           2            0.02               2.0
# 16    67           2            0.02               2.0
# 11    68           3            0.03               3.0
# 15    69           2            0.02               2.0
# 0     70           6            0.06               6.0

# %%
# Calcular la frecuencia acumulada
# Agregamos una nueva columna con el calculo
tabla_frecuencias ["Frec. Aacumulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec. Relativa  Frec. Porcentual  Frec. Aacumulada
# 20    18           2            0.02               2.0                 2
# 40    19           1            0.01               1.0                 3
# 30    20           1            0.01               1.0                 4
# 6     22           4            0.04               4.0                 8
# 8     23           3            0.03               3.0                11
# 22    25           2            0.02               2.0                13
# 44    26           1            0.01               1.0                14
# 38    28           1            0.01               1.0                15
# 5     29           4            0.04               4.0                19
# 7     30           4            0.04               4.0                23
# 19    31           2            0.02               2.0                25
# 37    32           1            0.01               1.0                26
# 41    33           1            0.01               1.0                27
# 33    34           1            0.01               1.0                28
# 17    35           2            0.02               2.0                30
# 32    36           1            0.01               1.0                31
# 4     37           4            0.04               4.0                35
# 27    38           2            0.02               2.0                37
# 2     39           4            0.04               4.0                41
# 13    40           3            0.03               3.0                44
# 35    41           1            0.01               1.0                45
# 10    43           3            0.03               3.0                48
# 18    44           2            0.02               2.0                50
# 39    45           1            0.01               1.0                51
# 14    46           3            0.03               3.0                54
# 42    47           1            0.01               1.0                55
# 3     48           4            0.04               4.0                59
# 9     49           3            0.03               3.0                62
# 28    50           2            0.02               2.0                64
# 12    51           3            0.03               3.0                67
# 25    52           2            0.02               2.0                69
# 34    53           1            0.01               1.0                70
# 1     54           4            0.04               4.0                74
# 23    55           2            0.02               2.0                76
# 29    56           2            0.02               2.0                78
# 36    58           1            0.01               1.0                79
# 26    59           2            0.02               2.0                81
# 43    60           1            0.01               1.0                82
# 24    62           2            0.02               2.0                84
# 31    64           1            0.01               1.0                85
# 21    66           2            0.02               2.0                87
# 16    67           2            0.02               2.0                89
# 11    68           3            0.03               3.0                92
# 15    69           2            0.02               2.0                94
# 0     70           6            0.06               6.0               100

# %%
# Libreria de funciones matematicas
import math
print(edades)
# Out:
# [54, 58, 59, 30, 51, 51, 50, 56, 70, 25, 23, 22, 30, 19, 43, 68, 38, 23, 37, 22, 48, 40, 46, 52, 38, 62, 62, 55, 66, 28, 30, 40, 46, 59, 50, 29, 37, 70, 18, 39, 51, 70, 60, 47, 39, 33, 37, 68, 29, 44, 35, 45, 67, 70, 52, 29, 32, 44, 55, 69, 20, 49, 25, 41, 53, 46, 30, 35, 34, 36, 31, 43, 18, 48, 54, 64, 31, 69, 23, 48, 43, 68, 56, 49, 22, 39, 54, 70, 48, 40, 70, 67, 66, 54, 26, 29, 37, 22, 39, 49]

# %%
df_edades_sturges = pd.DataFrame( { "Edad": edades})
df_edades_sturges
# Out:
#     Edad
# 0     54
# 1     58
# 2     59
# 3     30
# 4     51
# ..   ...
# 95    29
# 96    37
# 97    22
# 98    39
# 99    49
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos o clases utilizando la regla de Sturges
n = len(edades)
k = int(1 + math.log2(n))
print("Valor de n=", n, "\n Valor de K o número de intervalos o clases =", k)
# Out:
# Valor de n= 100
#  Valor de K o número de intervalos o clases = 7

# %%
plt.hist(edades, alpha =0.5, rwidth=0.95)
plt.title("Histograma de edades basado en valores estandar de matplotlib")
plt.hist(edades, color='thistle')
# Out:
# (array([11.,  4., 12., 10., 11., 14., 12.,  7.,  4., 15.]),
#  array([18. , 23.2, 28.4, 33.6, 38.8, 44. , 49.2, 54.4, 59.6, 64.8, 70. ]),
#  <BarContainer object of 10 artists>)

# %%
tabla_frec_sturges = pd.cut(df_edades_sturges["Edad"], bins = k).value_counts().reset_index()
tabla_frec_sturges
# Out:
#               index  Edad
# 0  (47.714, 55.143]    21
# 1  (32.857, 40.286]    18
# 2    (62.571, 70.0]    16
# 3  (17.948, 25.429]    13
# 4  (25.429, 32.857]    13
# 5  (40.286, 47.714]    11
# 6  (55.143, 62.571]     8

# %%
tabla_frec_sturges.columns = ["Clase", "Frecuencia"]
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (47.714, 55.143]          21
# 1  (32.857, 40.286]          18
# 2    (62.571, 70.0]          16
# 3  (17.948, 25.429]          13
# 4  (25.429, 32.857]          13
# 5  (40.286, 47.714]          11
# 6  (55.143, 62.571]           8

# %%
# Ordenar La tabla de frecuencias por la clase o el intervalo
tabla_frec_sturges.sort_values(by = "Clase")
tabla_frec_sturges
# Out:
#               Clase  Frecuencia
# 0  (47.714, 55.143]          21
# 1  (32.857, 40.286]          18
# 2    (62.571, 70.0]          16
# 3  (17.948, 25.429]          13
# 4  (25.429, 32.857]          13
# 5  (40.286, 47.714]          11
# 6  (55.143, 62.571]           8

# %%
tabla_frec_sturges["Frec. relativa"] = tabla_frec_sturges["Frecuencia"] / n
tabla_frec_sturges["Frec. porcentual"] = tabla_frec_sturges["Frecuencia"] / n * 100
tabla_frec_sturges["Frec. acumulada"] = tabla_frec_sturges["Frecuencia"].cumsum()
tabla_frec_sturges
# Out:
#               Clase  Frecuencia  Frec. relativa  Frec. porcentual  \
# 0  (47.714, 55.143]          21            0.21              21.0
# 1  (32.857, 40.286]          18            0.18              18.0
# 2    (62.571, 70.0]          16            0.16              16.0
# 3  (17.948, 25.429]          13            0.13              13.0
# 4  (25.429, 32.857]          13            0.13              13.0
# 5  (40.286, 47.714]          11            0.11              11.0
# 6  (55.143, 62.571]           8            0.08               8.0
#
#    Frec. acumulada
# 0               21
# 1               39
# 2               55
# 3               68
# 4               81
# 5               92
# 6              100

# %%
plt.hist(df_edades_sturges["Edad"], bins=k, alpha=0.5, rwidth=.95 , color='pink')
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
plt.boxplot(fabrica1)
plt.title("Producción de la fabrica 1")
plt.ylabel("Produccion en metros")
plt.show()

# %%
plt.boxplot(fabrica2)
plt.title("Producción de la fabrica 2")
plt.ylabel("Produccion en metros")
plt.show()

# %% [markdown]
# ### Ejemplo 6: Diagrama de caja y bigotes

# %%
fig, (ax1, ax2) = plt.subplots (nrows= 1, ncols=2, figsize=(9,5))
ax1.boxplot( fabrica1, vert = True, patch_artist=True)
ax1.set_title("Producción de la Fabrica 1")
ax2.boxplot( fabrica2, vert = True, patch_artist=True)
ax2.set_title("Producción de la Fabrica 2")
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [53.13, 50.29, 79.11, 61.82, 77.73, 75.16, 57.59, 93.45, 79.16, 73.93, 51.63, 78.92, 66.04, 85.48, 75.99, 77.62, 98.78, 93.41, 76.06, 85.67, 87.58, 75.64, 92.23, 82.8, 94.29, 81.03, 98.74, 82.95, 71.2, 96.68, 89.74, 85.15, 59.45, 74.97, 67.92, 51.18, 65.69, 66.49, 53.58, 51.91, 86.51, 51.29, 51.06, 90.29, 54.21, 97.04, 96.0, 87.55, 59.83, 66.4, 82.35, 59.22, 65.03, 60.91, 70.24, 90.94, 76.35, 80.93, 52.5, 64.98, 64.41, 53.01, 52.46, 77.0, 75.7, 54.77, 57.12, 59.15, 94.93, 52.2, 65.8, 84.44, 86.39, 67.09, 60.2, 73.04, 82.67, 98.13, 91.98, 60.1, 69.55, 96.26, 83.73, 90.61, 57.44, 91.39, 89.09, 77.21, 78.24, 82.23, 52.06, 63.05, 76.93, 78.79, 66.73, 86.93, 82.07, 78.82, 69.92, 63.2, 150]

# %%
plt.boxplot(fabrica1)
plt.title("Producción de la fabrica 1")
plt.ylabel("Produccion en metros")
plt.show()

# %%
fabrica2.append(150)
print(fabrica2)
# Out:
# [80.0, 69.73, 75.7, 98.67, 52.02, 50.15, 62.43, 65.87, 66.32, 82.36, 67.34, 96.98, 64.5, 94.17, 73.1, 55.76, 96.05, 91.82, 73.21, 60.75, 67.6, 79.17, 88.44, 94.56, 71.21, 72.24, 92.19, 57.08, 81.26, 62.32, 80.3, 52.57, 74.54, 70.74, 79.47, 77.96, 66.81, 60.83, 87.52, 59.26, 51.39, 82.21, 86.28, 50.75, 79.08, 94.68, 92.83, 51.24, 80.86, 93.66, 82.56, 56.07, 86.5, 97.31, 64.05, 67.61, 78.27, 70.88, 79.59, 55.99, 55.23, 85.92, 96.85, 81.4, 52.05, 79.61, 56.31, 92.06, 52.81, 61.34, 87.33, 83.38, 74.07, 67.95, 93.44, 64.96, 78.91, 52.36, 82.88, 81.66, 62.74, 90.37, 54.59, 68.07, 99.79, 93.96, 82.71, 76.91, 56.57, 63.7, 69.01, 75.29, 98.93, 89.5, 98.92, 73.29, 91.96, 96.11, 64.62, 81.37, 150]

# %%
plt.boxplot(fabrica2)
plt.title("Producción de la fabrica 2")
plt.ylabel("Produccion en metros")
plt.show()
